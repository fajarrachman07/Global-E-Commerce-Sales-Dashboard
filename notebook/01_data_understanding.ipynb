# %% [markdown]
# # I. Import Library & Upload Dataset

# %% [markdown]
# Memuat dataset dan memastikan data berhasil dibaca dengan benar sebelum analisa dilakukan

# %%
import pandas as pd

df = pd.read_csv("../data/global_ecommerce_sales.csv")

df.head()
# Out:
#     Order_ID  Order_Date   Customer_Name Customer_Segment        Country  \
# 0  ORD-11121  2023-01-02    Karen Suzuki        Corporate  United States
# 1  ORD-11244  2023-01-02  John Johansson        Corporate          Spain
# 2  ORD-10325  2023-01-03  Jessica Garcia         Consumer         Mexico
# 3  ORD-10467  2023-01-03    Clara Taylor        Corporate          Italy
# 4  ORD-11454  2023-01-05    Felix Thomas         Consumer          Italy
#
#           Region Product_Category                   Product_Name  Quantity  \
# 0  North America       Technology  Wireless Bluetooth Headphones         3
# 1         Europe       Technology     Mechanical Gaming Keyboard         4
# 2  North America  Office Supplies     Binder Clips Assorted 48pc         2
# 3         Europe       Technology                Webcam HD 1080p         2
# 4         Europe        Furniture        Standing Desk Converter         4
#
#    Unit_Price  Discount_Percent  Total_Sales  Shipping_Cost  Profit  \
# ...

# %% [markdown]
# Dataset berisi informasi transaksi e-commerce global yang mencakup identitas pesanan, tanggal transaksi, segmentasi pelanggan, lokasi geografis, kategori produk, serta metrik finansial seperti total sales, shipping cost, dan profit. Dari lima baris pertama terlihat bahwa transaksi berasal dari berbagai negara dan region seperti North America dan Europe, dengan variasi kategori produk seperti Technology, Furniture, dan Office Supplies. Struktur ini menunjukkan dataset siap digunakan untuk analisis performa penjualan lintas region, kategori produk, dan segmen pelanggan selama periode 2023–2025.

# %% [markdown]
# # II. Dataset Structure Overview

# %% [markdown]
# Memahami jumlah observasi, jumlah variabel data, serta tipe data setiap kolom untuk memastikan dataset siap
# digunakan dalam proses analisis lanjutan dan mengidentifikasi kolom yang memerlukan transformasi data

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Order_ID          2000 non-null   object
#  1   Order_Date        2000 non-null   object
#  2   Customer_Name     2000 non-null   object
#  3   Customer_Segment  2000 non-null   object
#  4   Country           2000 non-null   object
#  5   Region            2000 non-null   object
#  6   Product_Category  2000 non-null   object
#  7   Product_Name      2000 non-null   object
#  8   Quantity          2000 non-null   int64
#  9   Unit_Price        2000 non-null   float64
#  10  Discount_Percent  2000 non-null   int64
#  11  Total_Sales       2000 non-null   float64
#  12  Shipping_Cost     2000 non-null   float64
#  13  Profit            2000 non-null   float64
#  14  Payment_Method    2000 non-null   object
# dtypes: float64(4), int64(2), object(9)
# memory usage: 234.5+ KB

# %% [markdown]
# Dataset terdiri dari 2.000 baris dan 15 kolom yang mencakup informasi transaksi, karakteristik pelanggan, detail produk, serta metrik finansial seperti Total_Sales, Shipping_Cost, dan Profit. Seluruh kolom memiliki 2.000 nilai non-null, sehingga tidak ditemukan missing values pada dataset. Variabel numerik seperti Quantity, Unit_Price, Discount_Percent, Total_Sales, Shipping_Cost, dan Profit sudah memiliki tipe data yang sesuai untuk analisis kuantitatif. Namun, kolom Order_Date masih bertipe object sehingga perlu dikonversi ke format datetime agar dapat digunakan dalam analisis tren penjualan berbasis waktu.

# %% [markdown]
# # III. Descriptive Statistics Overview

# %% [markdown]
# Memahami distribusi awal variabel numerik seperti Quantity, Unit_Price, Discount_Percent, Total_Sales, Shipping_Cost, dan Profit untuk mengidentifikasi pola transaksi serta potensi faktor yang memengaruhi performa penjualan dan profitabilitas.

# %%
df.describe()
# Out:
#           Quantity   Unit_Price  Discount_Percent  Total_Sales  Shipping_Cost  \
# count  2000.000000  2000.000000       2000.000000  2000.000000     2000.00000
# mean      3.557500    73.329490          8.572500   242.279670       12.90212
# std       2.704506    79.311014          7.261274   382.583802        5.22319
# min       1.000000     3.030000          0.000000     2.420000        5.52000
# 25%       2.000000    18.757500          0.000000    41.227500        9.45750
# 50%       3.000000    46.420000         10.000000   113.125000       11.84500
# 75%       5.000000    90.250000         15.000000   266.552500       14.92000
# max      15.000000   472.560000         30.000000  3813.980000       40.44000
#
#             Profit
# count  2000.000000
# mean     79.436160
# std     137.573593
# min     -11.280000
# 25%       6.865000
# 50%      32.830000
# 75%      90.297500
# max    1373.630000

# %% [markdown]
# Distribusi Quantity menunjukkan bahwa sebagian besar transaksi berada pada skala pembelian kecil hingga menengah dengan rata-rata 3,56 unit per transaksi dan nilai maksimum mencapai 15 unit. Hal ini mengindikasikan bahwa transaksi dalam dataset didominasi oleh pembelian individual dibandingkan pembelian dalam jumlah besar.
#
# Variabel Unit_Price memiliki rentang yang cukup lebar, dari 3,03 hingga 472,56 USD, yang menunjukkan adanya variasi harga produk antar kategori dan berpotensi memengaruhi kontribusi revenue secara signifikan.
#
# Discount_Percent memiliki rata-rata 8,57% dengan nilai maksimum mencapai 30%, menunjukkan bahwa strategi diskon cukup sering digunakan dalam transaksi dan berpotensi memengaruhi margin keuntungan.
#
# Total_Sales memiliki distribusi yang sangat bervariasi dengan rata-rata 242,28 USD dan nilai maksimum mencapai 3813,98 USD, yang mengindikasikan adanya perbedaan kontribusi revenue antar produk atau kategori tertentu.
#
# Shipping_Cost relatif kecil dibandingkan Total_Sales dengan rata-rata sebesar 12,90 USD, namun tetap dapat memengaruhi profit pada transaksi dengan margin rendah.
#
# Variabel Profit memiliki nilai minimum negatif sebesar −11,28 USD, yang menunjukkan adanya transaksi yang menghasilkan kerugian dan perlu dianalisis lebih lanjut pada tahap exploratory data analysis untuk memahami faktor penyebabnya, seperti diskon tinggi atau biaya pengiriman.

# %% [markdown]
# # IV. Missing Values Check

# %% [markdown]
# Memastikan tidak ada nilai kosong (missing values) di dalam dataset yang dapat memengaruhi hasil analisis maupun
# visualisasi pada tahap selanjutnya.

# %%
df.isnull().sum()
# Out:
# Order_ID            0
# Order_Date          0
# Customer_Name       0
# Customer_Segment    0
# Country             0
# Region              0
# Product_Category    0
# Product_Name        0
# Quantity            0
# Unit_Price          0
# Discount_Percent    0
# Total_Sales         0
# Shipping_Cost       0
# Profit              0
# Payment_Method      0
# dtype: int64

# %% [markdown]
# Hasil pemeriksaan menunjukkan bahwa seluruh kolom dalam dataset memiliki jumlah nilai non-null sebanyak 2.000 observasi tanpa ditemukan missing values. Dengan demikian, dataset tidak memerlukan proses imputasi maupun penghapusan baris data dan siap digunakan untuk tahap data cleaning serta exploratory data analysis lanjutan.

# %% [markdown]
# # V. Duplicate Data Check

# %% [markdown]
# Memastikan setiap transaksi memiliki identifier unik sehingga tidak terjadi duplikasi data yang dapat memengaruhi akurasi analisis penjualan dan profitabilitas.

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# Hasil pemeriksaan menunjukkan tidak terdapat duplikasi pada kolom Order_ID maupun pada seluruh baris dataset. Hal ini menunjukkan bahwa setiap baris merepresentasikan transaksi yang unik sehingga dataset aman digunakan untuk analisis agregasi seperti perhitungan total sales, profit, dan performa per kategori produk.

# %% [markdown]
# # VI. Summary of Data Understanding

# %% [markdown]
# Dataset transaksi e-commerce global terdiri dari 2.000 observasi dan 15 variabel yang mencakup informasi pelanggan, kategori produk, wilayah geografis, serta metrik finansial seperti Total_Sales, Shipping_Cost, dan Profit. Seluruh kolom memiliki nilai lengkap tanpa missing values dan tidak ditemukan duplikasi transaksi berdasarkan Order_ID, sehingga dataset memiliki kualitas data yang baik untuk analisis lanjutan. Hasil statistik deskriptif menunjukkan adanya variasi nilai penjualan dan profit antar transaksi, serta ditemukan beberapa transaksi dengan profit negatif yang berpotensi dipengaruhi oleh strategi diskon atau biaya pengiriman. Selain itu, kolom Order_Date masih bertipe object dan perlu dikonversi menjadi datetime pada tahap data cleaning agar dapat digunakan dalam analisis tren berbasis waktu.
